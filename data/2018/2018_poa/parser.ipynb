# %%
import pandas as pd

# %%
widths = [6, 14, 13, 10]
df_f = pd.read_fwf("f_poa.txt", header=None, index_col=0)
df_m = pd.read_fwf("m_poa.txt", header=None, index_col=0)

# %%
pd.concat([df_m,df_f])
# Out:
#        1                                    2                     3        4   \
# 0
# 1      35                JURANDYR COUTO JUNIOR  JP/TREINAMENTO/RUNNI  2:21:41
# 2       6                  ALLISON ROCHA PERES       CIA DOS CAVALOS  2:23:17
# 3      34               MARCOS ALEXANDRE ELIAS                   NaN  2:23:55
# 4       9             EBERTH DA SILVA SILVéRIO         FRITAR/O2 FIT  2:24:49
# 5       2            LUIS FELIPE LEITE BARBOZA      VERTICAL PILATES  2:26:29
# ..    ...                                  ...                   ...      ...
# 852  4716                              CABRERA               DANIELA  6:11:38
# 853   509  KELLEN GOMES DE SOUZA ALMEIDA PADRO       VAMOS QUE VAMOS  6:14:00
# 854  3937              RENATA ALVES DE ALMEIDA           REGINA LIMA  6:15:06
# 855   876                     IVELISE GIAROLLA           NOVA EQUIPE  6:20:46
# 856   933                      ANDRESSA SOARES              RUN4SAVE  6:29:54
#
# ...
